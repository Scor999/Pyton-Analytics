# %% [markdown]
# ## <center>Практическое задание к лекции 4.

# %% [markdown]
# **1.2 Изучите стоимости недвижимости.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id               date     price  bedrooms  bathrooms  \
# 0      7129300520   20141013T000000   221900.0         3       1.00
# 1      6414100192   20141209T000000   538000.0         3       2.25
# 2      5631500400   20150225T000000   180000.0         2       1.00
# 3      2487200875   20141209T000000   604000.0         4       3.00
# 4      1954400510   20150218T000000   510000.0         3       2.00
# ...           ...                ...       ...       ...        ...
# 21608   263000018   20140521T000000   360000.0         3       2.50
# 21609  6600060120   20150223T000000   400000.0         4       2.50
# 21610  1523300141   20140623T000000   402101.0         2       0.75
# 21611   291310100   20150116T000000   400000.0         3       2.50
# 21612  1523300157   20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# **1.3 Изучите распределение квадратуры жилой.**

# %%
# plt.figure(figsize=(6, 6))
# sns.histplot(df['sqft_living'], bins=15);
# plt.title('распределение квадратуры жилой площади')
# plt.xlabel('жилая площадь')
# plt.ylabel('Кол-во')

# %% [markdown]
# **1.4 Изучите распределение года постройки.**

# %%
# plt.hist(df['yr_built'], color = 'blue', edgecolor = 'black',
#          bins = int(180/5))

# sns.distplot(df['yr_built'], hist=True, kde=False, 
#              bins=int(180/5), color = 'blue',
#              hist_kws={'edgecolor':'black'})
# plt.title('распределение года постройки')
# plt.xlabel('год постройки')
# plt.ylabel('Кол-во')

# %%
data = df[['price','sqft_living','yr_built']]
data.hist(figsize=(20, 20))
plt.show()

# %% [markdown]
# **2.1 Изучите распределение домов от наличия вида на набережную**
# *Постройте график*
# *Сделайте выводы*

# %%
data3 = df['waterfront'].value_counts()
data3.head()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
plt.pie(data3, autopct='%1.1f%%', labels=data3.index, )
plt.title('распределение домов от наличия вида на набережную')
# Out:
# Text(0.5, 1.0, 'распределение домов от наличия вида на набережную')

# %% [markdown]
# ---
#
# #### Вывод:
# Из гистограммы видно что большинство домов не имеет вид на набержную это $99,2\%$. И лишь всего $0,8\%$ домов имеют вид на набережную.
# ---

# %% [markdown]
# **2.2 Изучите распределение этажей домов.**

# %%
data4 = df['floors'].value_counts()
data4.head()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# Name: floors, dtype: int64

# %%
plt.figure(figsize=(4, 4))
sns.histplot(df['floors'], bins=15);
plt.title('распределение этажей домов.')
plt.xlabel('Кол-во этажей')
plt.ylabel('Кол-во домов')
# Out:
# Text(0, 0.5, 'Кол-во домов')

# %% [markdown]
# ---
#
# #### Вывод:
# Из гистограммы видно что большинство домов одноэтажные. На втором месте по распределению находятся двух этажные дома.
# ---

# %% [markdown]
# **2.2 Изучите распределение состояния домов**

# %%
data5 = df['condition'].value_counts()
data5.head()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
plt.figure(figsize=(4, 4))
sns.histplot(df['condition'], bins=15);
plt.title('распределение состояния домов.')
plt.xlabel('Состояние домов')
plt.ylabel('Кол-во домов')
# Out:
# Text(0, 0.5, 'Кол-во домов')

# %% [markdown]
# ---
#
# #### Вывод:
# Из гистограммы видно что большинство домов находятся в удовлетворительном состоянии.
# ---

# %% [markdown]
# **3.Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.**

# %%
sns.jointplot(x='price', y='sqft_living', data=df, kind='reg')
sns.jointplot(x='price', y='sqft_above', data=df, kind='reg')
sns.jointplot(x='price', y='grade', data=df, kind='reg')
sns.jointplot(x='price', y='bedrooms', data=df, kind='reg')
sns.jointplot(x='price', y='bathrooms', data=df, kind='reg')
sns.jointplot(x='price', y='yr_built', data=df, kind='reg')

# %% [markdown]
# ---
#
# #### Вывод:
# **На стоимость домов из графиков рассмотренных выше видно, что большое влияние на цену домов оказывают такие характиристики как:**
#     * Жилая площадь
#     * Общая площадь
#     * Состояние домов
#     * Дизайн
# **Остальные характеристики менее оказывают влияние на формирование цен на недвижимость.**
# ---
